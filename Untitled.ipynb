# %% [markdown]
# ### 信令服务器数量
#
# |             |     |
# | :-----      | ----:
# | 单房间人数上限    | 500
# | 支持最大人数     | 5000
#
#
# | 入会完成时间| 单房间qps峰值 |   mpc数量  |
# | :-----    | ----:| ----:
# |  1s内 | 500   |56
# |  2s内 | 250   |28
# | 4s内| 125   |14
#
#
# <center>以上qps 峰值是 （joinuser+pubstream）广播的估算值。</center>
#
#
# ### 媒体服务器数量
# |             |     |
# | :-----      | ----:
# | 媒体服务器带宽    | 300Mb
# | 推流码率     | 512kb
# | 单台支撑最大拉流|300路
# |5000路流需|17台
#
# ### 总计
# |             |     |
# | :-----      | ----:
# | 信令服务器      | 20
# | 媒体服务器      | 17
# |  总计     | 37
